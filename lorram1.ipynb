# %% [markdown]
# <a href="https://colab.research.google.com/github/lorramrj/AI-Fundamentals/blob/main/lorram1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Olá mundo')
# Out:
# Olá mundo
